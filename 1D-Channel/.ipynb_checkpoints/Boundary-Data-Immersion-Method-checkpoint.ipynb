# %% [markdown]
# <h1><center>Boundary Data Immersion Method (BDIM)</center></h1>
#
# ---
#
# <h3>Marin Lauber 2020</h3>

# %%
import numpy as np
import matplotlib.pyplot as plt
import NSsolver as ns
from scipy import optimize, linalg
try:
    plt.style.use("jupyter")
except OSError:
    print("Delaut syle in use")

# %% [markdown]
# <h2>1D Pipe Flow</h2>

# %%
def Body(x, X, t=10, e=2):
    # distance normalised by grid size
    d = abs((X - x)/(x[1]-x[0])) - t/2
    return d, mu_0(d, e), mu_1(d, e)

def kernel(d, e):
    return np.where(abs(d)<e, 0.5*(1+np.cos(d/e*np.pi)), 0)

def mu_0(d, e):
    return np.where(d<=-e, 0, np.where(abs(d)<e, 0.5*(1 + d/e + 1./np.pi*np.sin(d*np.pi/e)), 1.))
    
def mu_1(d, e):
    return np.where(abs(d)<e, e*(0.25- (d/(2*e))**2 - 1./(2*np.pi)*((d/e)*np.sin(d*np.pi/e) +\
                                                                   (1./np.pi)*(1+np.cos(d*np.pi/e)))), 0)

# %%
x, dx = np.linspace(-2, 2, 101, retstep=True)
d, mu0, mu1 = Body(x, 0, 10, 2)
plt.plot(x, kernel(d-2, e=2))
plt.plot(x, mu0, "-o", x, mu1, "-o");

# %%
def mu_0_dev(d):
    return np.where(d<0.5, 0, np.where(d>1, 1, 0.5*(1+np.cos(2*d*np.pi))))
x, dx = np.linspace(-2, 2, 301, retstep=True)
plt.plot(x, mu_0(x, 2), "-", x, mu_0_dev(x), "-");
plt.plot(x, np.where(x<0.5, 0, np.where(x>1., 0, 0.25*(1-np.cos(x*np.pi*4)))));
# plt.plot(x, mu_1_dev(x), "-o");

# %%
def update(x, u, V, X, dx, dt, t):
    
    # get body position
    d, mu0, mu1 = Body(x, X, t, e=2)
    
    # predict velocity 
    u_star = mu0*(u + dt*ns.r(u, dx)) + (1-mu0)*V + mu1*ns.ddn(u + dt*ns.r(u, dx) - V, dx)
    
    # get pressure
    sigma = ns.div(u_star, dx)
    p = ns.solve_pressure(mu0, sigma, dx)
    
    # correct
    u_n = u_star - dt*mu0*ns.grad(p, dx)
    
    return d, mu0, mu1, u_star, sigma, p, u_n

# %%
def draw_piston(plt, X, t=1, V=1):
    plt.fill([X-t/2,X-t/2,X+t/2,X+t/2], [-2*V,2*V,2*V,-2*V],fill=False,hatch='///')
    plt.quiver([X,X],[1.25*V,-1.25*V],[V,V],[0.,0.])

# %%
N = 64
x, dx = np.linspace(-1, 1, N, retstep=True)
xs = x + 0.5*dx # scalar cell-centred values
X = 0.0 #np.random.rand()-0.5
V = 1
u0 = np.zeros_like(x)
dt = 1.

d, mu, mu1, us, sigma, p, u_n = update(x, u0, V, X, dx, dt, 10)
print("Interface at X: %.2f" % X)
print(r"L inf %.3e" % np.max(np.abs(u_n -  V)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-191-526816d0e3c5> in <module>
#       7 dt = 1.
#       8
# ----> 9 d, mu, mu1, us, sigma, p, u_n = update(x, u0, V, X, dx, dt, 10)
#      10 print("Interface at X: %.2f" % X)
#      11 print(r"L inf %.3e" % np.max(np.abs(u_n -  V)))
#
# TypeError: update() takes 6 positional arguments but 7 were given

# %%
# plt.plot(x, mu1*ddn(u0 + r(u0, dx) - V, dx), ':k',lw=2,label=r"$\mu_1\partial_n(...)$")
plt.plot(x, us, '-.k', lw=1,label=r"$u^n$")
plt.plot(xs, sigma*.1, '-.', lw=1, label=r"div($u^n$)")
plt.plot(xs, p, '--k',  lw=1, label=r"$p^n$")
plt.plot(x, u_n, '-m', lw=1, label=r"$u^{n+1}$")
plt.vlines(X, 0, V, lw=1, color='red')
draw_piston(plt, X, t=0.02)
plt.legend()
plt.xlabel(r'$x/L$'); plt.xlim(-1,1); plt.ylim(-1,1.5);
plt.plot(x, p*kernel(d-2, e=2));
# plt.savefig('Figure_1.png', dpi=900);

# %%
def pforce(p, d):
    return np.sum(kernel(d-2., e=2.) * p)

# %%
N = 64
x, dx = np.linspace(-1, 1, N, retstep=True)
xs = x + 0.5*dx # scalar cell-centred values
X = 0.0 #np.random.rand()-0.5
V = 1
u0 = np.zeros_like(x)
dt = 0.1
pf = []
Nstep = 10

for _ in range(Nstep):
    d, mu, mu1, us, sigma, p, u_n = update(x, u0, V, X, dx, dt, 10)
    pf.append(pforce(p,d))
    X += dt*V
    u0 = u_n

# %%
plt.plot(x, us, '-.k', lw=1,label=r"$u^n$")
plt.plot(xs, p, '--k',  lw=1, label=r"$p^n$")
plt.plot(x, u_n, '-m', lw=1, label=r"$u^{n+1}$")
plt.vlines(X, 0, V, lw=1, color='red')
plt.legend()
plt.xlabel(r'$x/L$'); plt.xlim(-1,1); plt.ylim(-3,3);

# %%
# V = 1
# u0 = np.zeros_like(x)
# dt = 1.
# x, dx = np.linspace(-1, 1, N, retstep=True)
# Linf = np.empty((7, 11))

# for t in np.arange(0, 7):
#     for i, X in enumerate(np.linspace(0., dx/2, 11)):
#         _,_,_,_,_,u_n = update(x, u0, V, x[N//2]+X, dx, dt, t)
#         Linf[t, i] = np.max(np.abs(u_n -  V))

# plt.contourf(np.linspace(0., dx/2, 11)/dx, np.arange(0, 7), np.log(Linf), cmap="RdYlGn_r")
# plt.ylabel("t"); plt.xlabel("x-X/dx")
# plt.colorbar(label=r"Log(max($u^n - u^e$)");
# x, dx = np.linspace(-1, 1, 11, retstep=True)
# for t in np.arange(3, 6, 1): 
#     for S in np.linspace(0, dx/2, 3):
#         mu0, _ = Body(x, S, t, 2)
#         plt.plot(x, 1-mu0, "-", label=f"S: {(S/dx):.1f}      t: {t:.2f}")
# plt.legend();

# %% [markdown]
# # Now change the Kernel
#
# ---
#
# We can build a pressure field as we know what it should look like for an interface

# %%
def build_p(x, x_b, V):
    p = np.arange(0, len(x), 1)*V
    flipped = -np.flip(p[x>x_b])
    #ensures last term is correct
    corr = p[0] - flipped[-1] - V
    p[x>x_b] = flipped + corr
    p = p - np.mean(p)
    p[x==x_b] = (p[int(x_b-1)] + p[int(x_b+1)]) *.5
    return -p

# %%
N = 16
V=1
X =0
x, dx = np.linspace(-1, 1, N+1, retstep=True)

for i, X in enumerate(np.linspace(0., dx/2, 5)):
    p = build_p(x+0.5*dx, X+0.25*dx, V)
    plt.plot(x+0.5*dx, p, "-o");

# %% [markdown]
# we basically have to find a $\mu_f$ such that
#
# $$
#     \partial_x(\mu_f\partial_x p) = \partial_x(u^*) = \partial((1-mu_f)*V)
# $$
#
# for any potision $X$ of the interface

# %%
def f(mu_f):
    return abs(ns.div(mu_f*ns.grad(p, dx), dx) - V*ns.div(1-mu_f, dx))

# %%
def NSerror(muf, u, V):
    # predict velocity
    mu0 = np.ones_like(u); mu0[len(u)//2] = muf
    u_star = mu0*(u + ns.r(u, dx)) + (1-mu0)*V
    sigma = ns.div(u_star, dx)
    p = ns.solve_pressure(mu0, sigma, dx)
    u_n = u_star - dt*mu0*ns.grad(p, dx)
    return np.max(np.abs(u_n - np.ones_like(u_n)))

# %%
N = 32
muf0 = .6
u0 = np.zeros(N)
res = optimize.fsolve(NSerror, muf0, args=(u0, 1.))
print(res)
# Out:
# /anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# [-0.02610852]
# /anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:162: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)

# %%
NSerror(res, u0, 1.)
# Out:
# 0.46175006101388993

# %%
V=1
x, dx = np.linspace(-1, 1, N+1, retstep=True)
for i, X in enumerate(np.linspace(0., dx/2, 5)):
    p = build_p(x, X, V)
    muf = optimize.fsolve(f, np.ones_like(x))
    print(np.allclose(f(muf), 0.))
    plt.plot(x, 1-muf , "-s", label=f"{(X/dx):.2f}")
plt.legend();
# Out:
# True
# True
# True
# True
# True

# %%
def TopHat(x, X):
    dist = abs((X - x)/(x[1]-x[0]))
    mu_b = np.where(dist<=0.5, 1, 0)
    return 1.-mu_b

def Cosine(x, X):
    dist = abs((X - x)/(x[1]-x[0]))
#     mu_b = np.where(dist<=0.5,1,np.where(dist<=1.,.5*(1+np.cos(2*(dist-0.5)*np.pi)),0))
    mu_b = np.where(dist<=1,.5*(1+np.cos(dist*np.pi)),0)
    return 1.-mu_b

def Peskin(x, X):
    dist = abs((X - x)/(x[1]-x[0]))
    mu_b = np.where(dist<0.5,1./3.*(1+np.sqrt(-3*dist**2 + 1)),
                    np.where(dist<=1.5,1./6.*(5.-3*dist-np.sqrt(-3*(1.-dist)**2+1)),0.))
    return 1.-mu_b

def update(mu, u, V, dx, dt):
    
    # predict velocity 
    u_star = mu*(u + ns.r(u, dx)) + (1-mu)*V #+ mu1*ns.ddn(u + r(u, dx) - V, dx)
    
    # get pressure
    sigma = ns.div(u_star, dx)
    p = ns.solve_pressure(mu, sigma, dx)

    # correct
    u_n = u_star - dt*mu*ns.grad(p, dx)
    
    return u_star, sigma, p, u_n

# %%
N = 32
x, dx = np.linspace(-1, 1, N, retstep=True)
xs = x + 0.5*dx # scalar cell-centred values
X = np.random.rand()-0.5
V = 1
u0 = np.zeros_like(x)
dt = 1.

fig, ax = plt.subplots(1,3,sharey=True)
for i,kern in enumerate([TopHat, Cosine, Peskin]):
    mu = kern(x, X)
    us, sigma, p, u_n = update(mu, u0, V, dx, dt)
    print("Interface at X: %.2f" % X)
    print(r"L inf: %.3e" % np.max(np.abs(u_n -  V)))
    ax[i].plot(x, us, '-.k', lw=1,label=r"$u^n$")
    ax[i].plot(xs, sigma*.1, '-.', lw=1, label=r"div($u^n$)")
    ax[i].plot(xs, p, '--k',  lw=1, label=r"$p^n$")
    ax[i].plot(x, u_n, '-m', lw=1, label=r"$u^{n+1}$")
    ax[i].vlines(X, 0, V, lw=1, color='red')
    ax[i].set_xlim(-1,1); ax[i].set_ylim(-2,2);
    ax[i].set_xlabel(r'$x/L$');
ax[2].legend()
ax[0].set_ylabel(r'$U$')
# plt.savefig('kernel_comp.png', dpi=900);
# Out:
# Interface at X: 0.08
# L inf: 6.883e-15
# Interface at X: 0.08
# L inf: 9.002e-01
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: RuntimeWarning: invalid value encountered in sqrt
#
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in sqrt
#   from ipykernel import kernelapp as app
# Interface at X: 0.08
# L inf: 9.370e-01
# Text(0, 0.5, '$U$')

# %%
def update(mu, u, V, dx, dt):
    
    # predict velocity 
    u_star = mu*(u + ns.r(u, dx)) + (1-mu)*V #+ mu1*ns.ddn(u + r(u, dx) - V, dx)
    
    # get pressure
    sigma = ns.div(u_star, dx)
    p = ns.solve_pressure(mu, sigma, dx)

    # correct
    u_n = u_star - dt*mu*ns.grad(p, dx)
    
    return u_star, sigma, p, u_n

# %%
N = 32
x, dx = np.linspace(-1, 1, N, retstep=True)
xs = x + 0.5*dx # scalar cell-centred values
X = 0.23
V = 1
u0 = np.zeros_like(x)
dt = 1.

mu = TopHat(x, X)
us, sigma, p, u_n = update(mu, u0, V, dx, dt)
print("Interface at X: %.2f" % X)
print(r"L inf: %.3e" % np.max(np.abs(u_n -  V)))
plt.plot(x, us, '-.k', lw=1,label=r"$u^n$")
plt.plot(xs, sigma*.1, '-.', lw=1, label=r"div($u^n$)")
plt.plot(xs, p, '--k',  lw=1, label=r"$p^n$")
plt.plot(x, u_n, '-m', lw=1, label=r"$u^{n+1}$")
draw_piston(plt, X, t=0.015, V=2)
plt.legend()
plt.xlabel(r'$x/L$'); plt.xlim(-1,1); plt.ylim(-1.5,1.75);
# Out:
# Interface at X: 0.23
# L inf: 6.439e-15

# %%
from scipy import sparse, optimize, linalg
def Kernel(x, X):
    d = abs((X - x)/(x[1]-x[0]))
    mu = np.zeros_like(d)
    mu[d==np.min(d)] = 1.
    return 1.-mu

def TopHat(x, X):
    d = abs((X - x)/(x[1]-x[0]))
    mu_b = np.where(d<0.5, 1, np.where(d<1., 0.5*(1+np.cos(2*(d-.5)*np.pi)), 0.))
    return 1.-mu_b

# %%
N = 32
x, dx = np.linspace(-1, 1, N, retstep=True)
xs = x + 0.5*dx # scalar cell-centred values
X = 0.0*dx

fig, ax = plt.subplots(1, 2, sharey=True)
for j,k in enumerate([TopHat, Kernel]):
    beta = k(xs, X)
    ax[j].plot(xs, ns.div(beta), '-s')
plt.show()

fig, ax = plt.subplots(1, 2, sharey=True)
for j,k in enumerate([TopHat, Kernel]):
    beta = k(xs, X)
    L = ns.build_pressure_mat(beta, beta, dx)
    ax[j].imshow(L)

# %%
def thin_kernel(d, e=1.0, t=0.):
    return np.where(abs(d)-t/2<e, np.where(abs(d)<t/2, 1, 0.5*(1+np.cos((abs(d)-t/2)/e*np.pi))), 0)

d = np.linspace(-4, 4, 256)
plt.plot(d, thin_kernel(d, e=0.5, t=0), '-');

# %%
N = 32
x, dx = np.linspace(-1, 1, N, retstep=True)
xs = x + 0.5*dx         # scalar cell-centred values
X = 0.5*dx
V = 1
u0 = np.zeros_like(x)
dt = 1.

fig, ax = plt.subplots(1,3,figsize=(12,6))
for e in np.arange(1,8,1):
    mu = thin_kernel((x-X)/(x[1]-x[0]), e, 0.)
    div = ns.div(mu)
    ax[0].plot(xs, e+mu,  '-s')
    ax[1].plot(xs, e+div, '-o')
    print(sum(abs(div)))
    us, sigma, p, u_n = update(1.-mu, u0, V, dx, dt)
    ax[2].plot(x , e+p*0.4, '-o')
    print(r"L inf: %.3e" % np.max(np.abs(u_n -  V)))
    p = 0.; u_n = 0.
plt.show()
# Out:
# 2.0
# L inf: 6.883e-15
# 2.0
# L inf: 3.553e-15
# 2.0
# L inf: 4.330e-15
# 2.0
# L inf: 7.772e-15
# 2.0
# L inf: 6.994e-15
# 2.0
# L inf: 8.660e-15
# 2.0000000000000004
# L inf: 5.995e-15

# %%
for e in np.arange(1,8,1):
    mu = thin_kernel((x-X)/(x[1]-x[0]), e, 0.)
    L = ns.build_pressure_mat(1.-mu,mu,dx)
    plt.imshow(abs(L),cmap='binary'); plt.show()
    print(np.linalg.cond(L))
    us, sigma, p, u_n = update(1.-mu, u0, V, dx, dt)
    print(r"L inf: %.3e" % np.max(np.abs(u_n -  V)))
    p = 0.; u_n = 0.
# Out:
# 2.7647560614905108e+16
# L inf: 6.883e-15
# 2.3887455275838234e+17
# L inf: 3.553e-15
# 4.535852545292647e+16
# L inf: 4.330e-15
# 2.404833523311289e+16
# L inf: 7.772e-15
# 2.8438047070903144e+16
# L inf: 6.994e-15
# 2.5692858565080296e+16
# L inf: 8.660e-15
# 4.7422512510787816e+16
# L inf: 5.995e-15

# %%
d = np.linspace(-3,3,2**10)
e = 1
t = 1
plt.plot(d, thin_kernel(d, e, t), '-k');
d = np.arange(-3,3,1)
plt.plot(d, thin_kernel(d, e, t), 'ko')
plt.vlines(np.hstack((d,3)), 0, 1,linestyles='dotted');
plt.show()

# %% [markdown]
# ## Can we use different Kernels for velocity and pressure?

# %%
def update(mu_u, mu_p, u, V, dx, dt):
    
    # predict velocity 
    u_star = mu_u*(u + ns.r(u, dx)) + (1-mu_u)*V
    
    # get pressure
    sigma = ns.div(u_star, dx)
    p = ns.solve_pressure(mu_p, sigma, dx)

    # correct
    u_n = u_star - dt*mu_p*ns.grad(p, dx)
    
    return u_star, sigma, p, u_n

# %%
N = 32
x, dx = np.linspace(-1, 1, N, retstep=True)
xs = x - 0.5*dx # scalar cell-centred values
X = 0.5*dx
V = 1.
u0 = np.zeros_like(x)
dt = 1.
d = (x-X)/dx

# satandard kernel, with epsilon=2
mu_u = 1.-thin_kernel(d, 0.5, 2)

# pressure kernel that imposes the BCs
mu_p = 1.-thin_kernel(d, .5, 0)

# g is the difference between correct BC on velocity and actual BC
# g = np.zeros_like(u0) #(kern_var(xs, X, 1, 0.5) - (1.-mu_u))*V
# h = np.ones_like(g)

us, sigma, p, u_n = update(mu_u, mu_p, u0, V, dx, dt)

print(r"np.max(np.abs(u_n -  V)): %.3e" % np.max(np.abs(u_n -  V)))
# Out:
# np.max(np.abs(u_n -  V)): 5.773e-15

# %%
plt.plot(xs, 1.-mu_u,'-k', label=r'$\mu_u$')
plt.plot(xs, 1.-mu_p,':k', label=r'$\mu_p$')
# plt.plot(xs, us, '-s', label=r'$u^*=\mu_uV$')
plt.plot(x, p, '-o', label=r'$p$')
draw_piston(plt, X, t=0.015, V=2)
plt.plot(xs, -mu_p*ns.grad(p, dx), '--s', label=r'$-\mu_p\nabla p$')
plt.plot(xs, u_n, '-s', label=r'$u_{n+1}$')
plt.legend()
plt.show()

# %% [markdown]
# as long as the right amount of divergence (from the body BC's) is introduced into the flow, and the correct pressure BC's are imposed, the correct answer is obtained, even for different kernels.

# %%
mu_u = 1.-thin_kernel((x-0.5*dx)/dx, .5, 0.)
plt.plot(x, ns.div(mu_u), '-o');

# %%
def GaussinaKernel(d, e, t=1):
    return np.where(abs(d)<=t, 1, np.exp(-(e*(abs(d)-t))**2))
def CosineKernel(d, e, t=2):
    return np.where(abs(d)<=t, 1, np.where(abs(d)<e, 0.5*(1+np.cos(1/(e-t)*(abs(d)-t)*np.pi)), 0.))

# %%
d = np.linspace(-4,4,256)
plt.plot(d, GaussinaKernel(d, e=2.5, t=1), label="Gaussian")
plt.plot(d, CosineKernel(d, e=2., t=1), label="Cosine")
plt.legend();

# %%
def build_new_pressure_mat(d, sigma, dx, show=False):
    
    # lower diagonals are just the beta coefficients
    L = sparse.diags([1.,-2.,1.],[-1,0,1],shape=(len(sigma),len(sigma))).toarray()
    L[0,-1] = L[0,1]; L[-1,0] = L[-1,-2]
    
    # adjust stencil around boundary
    idx = int(np.argwhere(np.isclose(abs(d), 0.0)))
    L[idx-1,:] = 0.; L[idx,:] = 0.
    L[idx-1,idx-4:idx] = np.array([0., 0., 1., -1.])
    L[idx,idx:idx+4]= np.array([ -1., 1., 0., 0.])
    
    # sclae by grid size
    L *= dx**(-2)
    
    if show:
        p = plt.imshow(abs(L),cmap='binary')
        plt.colorbar(p)
        plt.show()
    return L

def solve_pressure(d, sigma, dx):
    
    L = build_new_pressure_mat(d, sigma, dx)
    
    # solve using jacobi
    p = ns.Jacobi(L, sigma, 5000)
    
    return p - p.mean() # zero mean

def update(d, mu, u, V, dx, dt):
    
    # predict velocity 
    u_star = mu*(u + ns.r(u, dx)) + (1-mu)*V
    
    # get pressure
    sigma = ns.div(u_star, dx)
    p = solve_pressure(d, sigma, dx)

    # correct
    u_n = u_star - dt*mu*ns.grad(p, dx)
    
    return u_star, sigma, p, u_n

# %%
N = 32
x, dx = np.linspace(-1, 1, N, retstep=True)
X = 0.5*dx
d = (x-X)/dx

# %%
L1 = build_new_pressure_mat(d, np.ones_like(d), dx, True)

# %%
L2 = ns.build_pressure_mat(1.-thin_kernel(d, 0.5, 0.), d, dx, True)

# %% [markdown]
# Check that both matrix correspond when the stencil is changed to BDIM

# %%
print(np.allclose(L1, L2))
# Out:
# True

# %%
N = 32
x, dx = np.linspace(-1, 1, N, retstep=True)
xs = x + 0.5*dx # scalar cell-centred values
X = 0.5*dx
V = 1.
u0 = np.zeros_like(x)
dt = 1.
d = (x-X)/dx
# satandard kernel, with epsilon=2
mu = 1.-thin_kernel(d, 0.5, .0)

us, sigma, p, u_n = update(d, mu, u0, V, dx, dt)

print(r"np.max(np.abs(u_n -  V)): %.3e" % np.max(np.abs(u_n -  V)))
# Out:
# np.max(np.abs(u_n -  V)): 6.883e-15

# %%
plt.plot(x, us,'k', label=r'$u_s$')
plt.plot(xs, ns.div(us),'-C3', label=r'$div(u_s)$')
plt.plot(xs, p, '-', label=r'$p$')
draw_piston(plt, X, 0.015, 1)
plt.plot(xs, u_n, '-', label=r'$u_{n+1}$')
plt.legend(); plt.ylim(-1.5, 2); plt.xlim(-1,1)
plt.xlabel(r'$x/L$')
plt.show()
